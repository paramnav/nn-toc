# %% [markdown]
# ### Train DNN

# %%
import torch
from pathlib import Path
import pickle
import numpy as np
from matplotlib import pyplot as plt
#from sklearn.model_selection import StratifiedKFold, KFold
#from sklearn.model_selection import train_test_split
import os
from torch.utils.data import Dataset, TensorDataset, DataLoader
np.random.seed(42)
torch.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


import torch.nn.functional as F
import sys
module_path = Path().resolve().parents[1] / "src" / "models"

# Append the directory to sys.path
sys.path.append(str(module_path))


from trainDNN import *
from explainDNN import *
from predictDNN import *

module_path = Path().resolve().parents[1] / "src" / "postprocessing"

# Append the directory to sys.path
sys.path.append(str(module_path))


from getModelPerformance import *
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# #### Load features

# %%
feature_path = Path().resolve().parents[1] / "data" / "interim" / "inputfeatures" / "SedTOCFeaturesnoNAN_TOC_CS_men_secondhalf_84_1"
features = np.load(Path(feature_path / "numpy_features.npy"))
labels = np.load(Path(feature_path / "numpy_labels.npy"))
lats = np.load(Path(feature_path / "numpy_lat.npy"))
lons = np.load(Path(feature_path / "numpy_lon.npy"))
X_mean = np.load(Path(feature_path / "features_mean.npy")).astype(float)
X_std = np.load(Path(feature_path / "features_std.npy")).astype(float)

# %%
features.shape[1]
# Out:
# 139

# %%
features
# Out:
# array([[2.81831435e-01, 6.60764719e+04, 9.99990000e+04, ...,
#         0.00000000e+00, 0.00000000e+00, 5.00000007e-02],
#        [5.43216231e-01, 2.43577461e+02, 9.99990000e+04, ...,
#         0.00000000e+00, 0.00000000e+00, 3.28210402e+00],
#        [3.41891410e+00, 9.41443887e-01, 9.99990000e+04, ...,
#         0.00000000e+00, 0.00000000e+00, 1.68704844e+00],
#        ...,
#        [1.78527627e+00, 1.14610092e+03, 4.25606890e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 8.57157856e-02],
#        [1.61352936e+00, 4.73632957e-01, 9.99990000e+04, ...,
#         0.00000000e+00, 0.00000000e+00, 8.20304990e-01],
#        [3.19964562e+00, 3.94659580e-01, 2.55213238e+04, ...,
#         0.00000000e+00, 0.00000000e+00, 1.25000000e+00]])

# %% [markdown]
# #### Define the neural network architecture

# %%
loss_fn = torch.nn.MSELoss()

# %%
class DNN(torch.nn.Module):
    def __init__(self, layer_width):
        super(DNN, self).__init__()

        self.do_prob = 0.2
        self.encoder = torch.nn.Sequential(
            torch.nn.Linear(features.shape[1], layer_width[0]),
            torch.nn.BatchNorm1d(layer_width[0]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[0], layer_width[1]),
            torch.nn.BatchNorm1d(layer_width[1]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[1], layer_width[2]),
            torch.nn.BatchNorm1d(layer_width[2]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[2], layer_width[3]),
            torch.nn.BatchNorm1d(layer_width[3]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[3], layer_width[4]),
            torch.nn.BatchNorm1d(layer_width[4]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[4], layer_width[5]),
            torch.nn.BatchNorm1d(layer_width[5]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[5], layer_width[6]),
            torch.nn.BatchNorm1d(layer_width[6]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),

        )

        self.decoder = torch.nn.Sequential(

            # torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[6], layer_width[5]),
            #torch.nn.BatchNorm1d(layer_width[5]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[5], layer_width[4]),
            #torch.nn.BatchNorm1d(layer_width[4]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[4], layer_width[3]),
            #torch.nn.BatchNorm1d(layer_width[3]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[3], layer_width[2]),
            #torch.nn.BatchNorm1d(layer_width[2]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[2], layer_width[1]),
            #torch.nn.BatchNorm1d(layer_width[1]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[1], layer_width[0]),
            #torch.nn.BatchNorm1d(layer_width[0]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[0], features.shape[1])
        )

        self.supervised = torch.nn.Sequential(
            torch.nn.Linear(layer_width[6], layer_width[7]),
            torch.nn.BatchNorm1d(layer_width[7]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[7], layer_width[8]),
            torch.nn.BatchNorm1d(layer_width[8]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[8], layer_width[9]),
            torch.nn.BatchNorm1d(layer_width[9]),
            torch.nn.ReLU(),
            torch.nn.Dropout(self.do_prob),
            torch.nn.Linear(layer_width[9], 1),

        )
        
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        targets = self.supervised(encoded)
        #return decoded, targets
        return targets
        
def initialize_weights(m):

    if isinstance(m, torch.nn.Linear):
        torch.nn.init.kaiming_normal_(m.weight.data)
        torch.nn.init.constant_(m.bias.data, 0)

# %%
layer_widths = [512, 512, 512, 512, 512, 512, 512, 512, 512, 512]  # Define your desired layer widthsmodel = DNN(layer_widths)#DNN(input_dim, layer_widths)
model = DNN(layer_widths)#DNN(input_dim, layer_widths)
model.apply(initialize_weights)
model.double()
# Out:
# DNN(
#   (encoder): Sequential(
#     (0): Linear(in_features=139, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Linear(in_features=512, out_features=512, bias=True)
#     (9): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Linear(in_features=512, out_features=512, bias=True)
#     (13): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): Dropout(p=0.2, inplace=False)
#     (16): Linear(in_features=512, out_features=512, bias=True)
#     (17): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU()
#     (19): Dropout(p=0.2, inplace=False)
#     (20): Linear(in_features=512, out_features=512, bias=True)
#     (21): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU()
#     (23): Dropout(p=0.2, inplace=False)
#     (24): Linear(in_features=512, out_features=512, bias=True)
#     (25): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU()
#     (27): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=512, out_features=512, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Linear(in_features=512, out_features=512, bias=True)
#     (10): ReLU()
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Linear(in_features=512, out_features=512, bias=True)
#     (13): ReLU()
#     (14): Dropout(p=0.2, inplace=False)
#     (15): Linear(in_features=512, out_features=512, bias=True)
#     (16): ReLU()
#     (17): Dropout(p=0.2, inplace=False)
#     (18): Linear(in_features=512, out_features=139, bias=True)
#   )
#   (supervised): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Linear(in_features=512, out_features=512, bias=True)
#     (9): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Linear(in_features=512, out_features=1, bias=True)
#   )
# )

# %%
model = DNN(layer_widths)
model = model.double()
model.apply(initialize_weights)

torch.manual_seed(42)

# %%
#time intensive operation(better save processed features and labels, after first run)
features, labels, lats, lons = preprocess_features_labels(features, labels, lats, lons, X_mean, X_std) 
np.save("preprocessed/features_CS_secondhalf_84_1", features)
np.save("preprocessed/labels_CS_secondhalf_84_1", labels)
np.save("preprocessed/lats_CS_secondhalf_84_1", lats)
np.save("preprocessed/lons_CS_secondhalf_84_1", lons)
# Out:
# Duplicate row with index [10221 12854 14151 20055 21178 24877 29883] was in group 25 and was replaced with NaN values
# Duplicate row with index [ 7296 35451] was in group 59 and was replaced with NaN values
# Duplicate row with index [10327 23981] was in group 71 and was replaced with NaN values
# Duplicate row with index [ 7922  9454 13916 24192 26054 31753] was in group 131 and was replaced with NaN values
# Duplicate row with index [ 8618 31174 33771 35340] was in group 132 and was replaced with NaN values
# Duplicate row with index [18469 20736 24505 31478 34157] was in group 176 and was replaced with NaN values
# Duplicate row with index [ 7614 17700] was in group 193 and was replaced with NaN values
# Duplicate row with index [ 6472  8765 10230 10770 11381 11911 15187 16190 21696 21925 26442 28381
#  30079 35153] was in group 204 and was replaced with NaN values
# Duplicate row with index [ 7451  9766 20496 24329] was in group 210 and was replaced with NaN values
# Duplicate row with index [12140 13020 13064 33971] was in group 265 and was replaced with NaN values
# Duplicate row with index [ 7608 12159 28672 30027] was in group 272 and was replaced with NaN values
# Duplicate row with index [29516 29924 35098] was in group 294 and was replaced with NaN values
# Duplicate row with index [ 9050 23545] was in group 305 and was replaced with NaN values
# Duplicate row with index [ 7808 32767] was in group 352 and was replaced with NaN values
# Duplicate row with index [10093 15937] was in group 364 and was replaced with NaN values
# Duplicate row with index [ 7743  9877 10730 13601 18467 20718 29952 31263] was in group 377 and was replaced with NaN values
# Duplicate row with index [21937 30706] was in group 399 and was replaced with NaN values
# Duplicate row with index [ 6428  8288 19042 33282] was in group 408 and was replaced with NaN values
# Duplicate row with index [ 7953 23729 28573] was in group 412 and was replaced with NaN values
# Duplicate row with index [ 9016 34689] was in group 426 and was replaced with NaN values
# Duplicate row with index [13312 15802 18555 20099 21487 32758] was in group 475 and was replaced with NaN values
# Duplicate row with index [30920 34585] was in group 510 and was replaced with NaN values
# Duplicate row with index [17418 18784 20100 24655 26872 26941] was in group 536 and was replaced with NaN values
# Duplicate row with index [ 7237 20533] was in group 538 and was replaced with NaN values
# Duplicate row with index [ 6694  6697  8395  8837 10774 12449 17402 19148 20650 20879 23055 23773
#  24875 25119 26793 30614 30916 31847 32851 33148 35342] was in group 539 and was replaced with NaN values
# Duplicate row with index [16804 18470 26465 27595] was in group 543 and was replaced with NaN values
# Duplicate row with index [17069 17337] was in group 551 and was replaced with NaN values
# Duplicate row with index [ 8840 13442 19043 27571 34376] was in group 567 and was replaced with NaN values
# Duplicate row with index [ 6139 16333 25210 28809 34554] was in group 570 and was replaced with NaN values
# Duplicate row with index [20848 32606] was in group 601 and was replaced with NaN values
# Duplicate row with index [ 9548 10055 12645 13780 15483 16947 17230 21296 29008 30417 32170 34663
#  34964] was in group 648 and was replaced with NaN values
# Duplicate row with index [17027 26168] was in group 719 and was replaced with NaN values
# Duplicate row with index [ 7978 13121 24081 25744 34280] was in group 732 and was replaced with NaN values
# Duplicate row with index [11447 18287] was in group 739 and was replaced with NaN values
# Duplicate row with index [ 7403 26373 27482] was in group 740 and was replaced with NaN values
# Duplicate row with index [15007 25017 34221] was in group 758 and was replaced with NaN values
# Duplicate row with index [ 5844  9888 14430 15055 17666 19996 20257 22589 22776 23570 28948 34474] was in group 764 and was replaced with NaN values
# Duplicate row with index [ 5932  6159  7789  8441  8578  8676  9152 10273 10539 10646 11999 13199
#  14583 14651 15082 16722 16946 18242 18796 22136 22621 23035 23681 23949
#  23998 25752 26088 26789 26961 29197 29242 29248 29334 29393 29716 29782
#  30707 30734 30807 30854 30859 32291 32329 32352 32992 33153 34694] was in group 776 and was replaced with NaN values
# Duplicate row with index [14927 28138 33704 35094] was in group 818 and was replaced with NaN values
# Duplicate row with index [12067 12843] was in group 823 and was replaced with NaN values
# Duplicate row with index [11245 12444 29802] was in group 905 and was replaced with NaN values
# Duplicate row with index [ 7746 29107] was in group 911 and was replaced with NaN values
# Duplicate row with index [13862 29290 33507] was in group 934 and was replaced with NaN values
# Duplicate row with index [11005 12061 12860 17071 17925 18284 18441 27592 29287 30924 33061 34861] was in group 968 and was replaced with NaN values
# Duplicate row with index [12822 15927 33512] was in group 1045 and was replaced with NaN values
# Duplicate row with index [20536 28982] was in group 1166 and was replaced with NaN values
# Duplicate row with index [ 8165 26109 33217] was in group 1229 and was replaced with NaN values
# Duplicate row with index [11194 24922] was in group 1230 and was replaced with NaN values
# Duplicate row with index [14361 24437 28669 31589] was in group 1374 and was replaced with NaN values
# Duplicate row with index [16235 29200] was in group 1381 and was replaced with NaN values
# Duplicate row with index [10368 11774 18185 22611 27215 33208 34651] was in group 1388 and was replaced with NaN values
# Duplicate row with index [21899 28712] was in group 1409 and was replaced with NaN values
# Duplicate row with index [ 8149 16503 22495 28607 31257] was in group 1477 and was replaced with NaN values
# Duplicate row with index [ 9998 18765 34833] was in group 1495 and was replaced with NaN values
# Duplicate row with index [27579 31025] was in group 1507 and was replaced with NaN values
# Duplicate row with index [30622 31165] was in group 1523 and was replaced with NaN values
# Duplicate row with index [13886 23701 27615] was in group 1555 and was replaced with NaN values
# Duplicate row with index [ 7957 10195 11095 12750] was in group 1556 and was replaced with NaN values
# Duplicate row with index [ 9896 19417 31924 34425] was in group 1572 and was replaced with NaN values
# Duplicate row with index [10613 11586 14869] was in group 1719 and was replaced with NaN values
# Duplicate row with index [12382 21045] was in group 1729 and was replaced with NaN values
# Duplicate row with index [14367 20874 25004] was in group 1746 and was replaced with NaN values
# Duplicate row with index [16054 33059] was in group 1807 and was replaced with NaN values
# Duplicate row with index [15404 32671] was in group 1845 and was replaced with NaN values
# Duplicate row with index [ 8276 24791 30426 34729] was in group 1870 and was replaced with NaN values
# Duplicate row with index [10634 13174 13438 13474 19732 24246 25789 27185] was in group 1878 and was replaced with NaN values
# Duplicate row with index [16183 18169 25594] was in group 1883 and was replaced with NaN values
# Duplicate row with index [15413 16974 20334 26831 28890] was in group 1894 and was replaced with NaN values
# Duplicate row with index [21910 33193] was in group 1898 and was replaced with NaN values
# Duplicate row with index [ 8848 23978 33274] was in group 1945 and was replaced with NaN values
# Duplicate row with index [17752 20803 21724 24433 27756] was in group 1959 and was replaced with NaN values
# Duplicate row with index [30404 31164] was in group 1978 and was replaced with NaN values
# Duplicate row with index [ 7816 29947] was in group 1990 and was replaced with NaN values
# Duplicate row with index [15254 24147] was in group 1991 and was replaced with NaN values
# Duplicate row with index [18713 19151 22100 29584] was in group 2002 and was replaced with NaN values
# Duplicate row with index [15080 24780 33504 34780] was in group 2020 and was replaced with NaN values
# Duplicate row with index [ 8734 11918] was in group 2022 and was replaced with NaN values
# Duplicate row with index [10810 14478 15087 15109 17871 19537 24390 29766 33151 33761] was in group 2026 and was replaced with NaN values
# Duplicate row with index [ 5851  9241 30828] was in group 2027 and was replaced with NaN values
# Duplicate row with index [23805 25462 34798] was in group 2037 and was replaced with NaN values
# Duplicate row with index [ 6647 16592 24400] was in group 2044 and was replaced with NaN values
# Duplicate row with index [ 8219  9633 29627] was in group 2062 and was replaced with NaN values
# Duplicate row with index [ 8681 17510 25596 26719] was in group 2070 and was replaced with NaN values
# Duplicate row with index [13536 14543 16432 32415] was in group 2082 and was replaced with NaN values
# Duplicate row with index [15305 20585] was in group 2097 and was replaced with NaN values
# Duplicate row with index [12797 20538 33633] was in group 2133 and was replaced with NaN values
# Duplicate row with index [21649 33513] was in group 2204 and was replaced with NaN values
# Duplicate row with index [23737 23929] was in group 2248 and was replaced with NaN values
# Duplicate row with index [13679 18190 30803 33666] was in group 2275 and was replaced with NaN values
# Duplicate row with index [ 6489 16270 29557 33320] was in group 2281 and was replaced with NaN values
# Duplicate row with index [15039 15665 28504] was in group 2282 and was replaced with NaN values
# Duplicate row with index [ 8352 12536 30885] was in group 2289 and was replaced with NaN values
# Duplicate row with index [ 6417 15162] was in group 2290 and was replaced with NaN values
# Duplicate row with index [17062 31561] was in group 2334 and was replaced with NaN values
# Duplicate row with index [11757 13799 17009 26718] was in group 2381 and was replaced with NaN values
# Duplicate row with index [ 6289  7749 14814 21711] was in group 2420 and was replaced with NaN values
# Duplicate row with index [27387 33556] was in group 2483 and was replaced with NaN values
# Duplicate row with index [ 5942 25386] was in group 2500 and was replaced with NaN values
# Duplicate row with index [10792 25191] was in group 2503 and was replaced with NaN values
# Duplicate row with index [ 6249 12747 15970 21583] was in group 2544 and was replaced with NaN values
# Duplicate row with index [ 6877 14898 27570 28305] was in group 2565 and was replaced with NaN values
# Duplicate row with index [ 8333 22423] was in group 2572 and was replaced with NaN values
# Duplicate row with index [24501 28715] was in group 2588 and was replaced with NaN values
# Duplicate row with index [10369 24629 29905] was in group 2595 and was replaced with NaN values
# Duplicate row with index [ 5803 14777] was in group 2713 and was replaced with NaN values
# Duplicate row with index [ 6730  7421  7939 11051 11882 14045 14290 15987 18706 19865 20193 22467
#  23675 24951 26494 27737 28244 28821 30025 31061 31282 32056 32267] was in group 2748 and was replaced with NaN values
# Duplicate row with index [17577 22862 33276] was in group 2752 and was replaced with NaN values
# Duplicate row with index [19502 24536] was in group 2762 and was replaced with NaN values
# Duplicate row with index [17068 21235] was in group 2765 and was replaced with NaN values
# Duplicate row with index [ 8327 12562 12580 17928 19647 19767 19938 23233 24190 25120 32577] was in group 2778 and was replaced with NaN values
# Duplicate row with index [17552 34810] was in group 2784 and was replaced with NaN values
# Duplicate row with index [13507 28412 30487 31861 34070] was in group 2799 and was replaced with NaN values
# Duplicate row with index [ 9648 20405 22796] was in group 3042 and was replaced with NaN values
# Duplicate row with index [ 6690 14031 25392] was in group 3085 and was replaced with NaN values
# Duplicate row with index [ 6005 21707 26113] was in group 3117 and was replaced with NaN values
# Duplicate row with index [ 9612 27655] was in group 3217 and was replaced with NaN values
# Duplicate row with index [10964 32374] was in group 3307 and was replaced with NaN values
# Duplicate row with index [ 6399 10623 16078 20713] was in group 3330 and was replaced with NaN values
# Duplicate row with index [14914 30120] was in group 3407 and was replaced with NaN values
# Duplicate row with index [13457 16672] was in group 3410 and was replaced with NaN values
# Duplicate row with index [11687 14014 15902] was in group 3477 and was replaced with NaN values
# Duplicate row with index [ 7276 12696 13781 24060] was in group 3479 and was replaced with NaN values
# Duplicate row with index [14395 30232] was in group 3481 and was replaced with NaN values
# Duplicate row with index [ 7378 13073 30050] was in group 3505 and was replaced with NaN values
# Duplicate row with index [ 8010 12406 18873 23632] was in group 3567 and was replaced with NaN values
# Duplicate row with index [10981 12817 16599 18817 27790 34171] was in group 3591 and was replaced with NaN values
# Duplicate row with index [ 8007  9616 26574] was in group 3617 and was replaced with NaN values
# Duplicate row with index [ 7428  7557 16991 17882 25444] was in group 3670 and was replaced with NaN values
# Duplicate row with index [15479 23000 35066] was in group 3671 and was replaced with NaN values
# Duplicate row with index [ 6478  8546 13639 20629] was in group 3675 and was replaced with NaN values
# Duplicate row with index [ 9475 27222] was in group 3746 and was replaced with NaN values
# Duplicate row with index [15290 30715 33112] was in group 3747 and was replaced with NaN values
# Duplicate row with index [14747 24983 28936] was in group 3751 and was replaced with NaN values
# Duplicate row with index [14931 23954 24102] was in group 3829 and was replaced with NaN values
# Duplicate row with index [ 6421  7325 11659 15002 17602 18513 19397 19779 21857 24912 25491 33907
#  34029] was in group 3944 and was replaced with NaN values
# Duplicate row with index [22464 25262 30391 31502] was in group 3990 and was replaced with NaN values
# Duplicate row with index [11544 22965] was in group 4000 and was replaced with NaN values
# Duplicate row with index [10632 18581 29271] was in group 4012 and was replaced with NaN values
# Duplicate row with index [ 7067  9642 18654 19121 29326 33684] was in group 4077 and was replaced with NaN values
# Duplicate row with index [10330 10567 21785 27630 34074] was in group 4107 and was replaced with NaN values
# Duplicate row with index [ 7444 11895 14818 22357] was in group 4134 and was replaced with NaN values
# Duplicate row with index [20301 23927 25607 27131 30689] was in group 4200 and was replaced with NaN values
# Duplicate row with index [ 6008  6486 28131] was in group 4217 and was replaced with NaN values
# Duplicate row with index [12053 30129 31152 33084] was in group 4230 and was replaced with NaN values
# Duplicate row with index [7994 9658] was in group 4276 and was replaced with NaN values
# Duplicate row with index [ 9315 29581] was in group 4305 and was replaced with NaN values
# Duplicate row with index [ 7576 10380 28297 32051] was in group 4338 and was replaced with NaN values
# Duplicate row with index [10726 20970 22829 31380 32941] was in group 4381 and was replaced with NaN values
# Duplicate row with index [14810 20372] was in group 4400 and was replaced with NaN values
# Duplicate row with index [10325 23261 28437 29596] was in group 4418 and was replaced with NaN values
# Duplicate row with index [11555 19233] was in group 4422 and was replaced with NaN values
# Duplicate row with index [28286 32260 32450 34751] was in group 4475 and was replaced with NaN values
# Duplicate row with index [21848 29768 34660] was in group 4502 and was replaced with NaN values
# Duplicate row with index [24686 30254] was in group 4565 and was replaced with NaN values
# Duplicate row with index [ 6936  7198 20135 28556] was in group 4572 and was replaced with NaN values
# Duplicate row with index [ 6439 21489 27493 30333] was in group 4618 and was replaced with NaN values
# Duplicate row with index [11926 15629] was in group 4631 and was replaced with NaN values
# Duplicate row with index [10498 15264 19100 34926] was in group 4651 and was replaced with NaN values
# Duplicate row with index [14333 18214 21348] was in group 4701 and was replaced with NaN values
# Duplicate row with index [25560 31757] was in group 4712 and was replaced with NaN values
# Duplicate row with index [17257 18728] was in group 4788 and was replaced with NaN values
# Duplicate row with index [ 9299 12008] was in group 4789 and was replaced with NaN values
# Duplicate row with index [ 9469 27594] was in group 4803 and was replaced with NaN values
# Duplicate row with index [10645 12672 14105 25220 35533] was in group 4846 and was replaced with NaN values
# Duplicate row with index [18550 21855 29218] was in group 4900 and was replaced with NaN values
# Duplicate row with index [14011 19658 22685 35344] was in group 4916 and was replaced with NaN values
# Duplicate row with index [14598 16057 32829 33067] was in group 4917 and was replaced with NaN values
# Duplicate row with index [12856 16931 26161 32611 33945 35145] was in group 4948 and was replaced with NaN values
# Duplicate row with index [11515 20318 27773] was in group 4993 and was replaced with NaN values
# Duplicate row with index [19508 27206 30176] was in group 5008 and was replaced with NaN values
# Duplicate row with index [16813 30400] was in group 5018 and was replaced with NaN values
# Duplicate row with index [15803 26843 31124] was in group 5162 and was replaced with NaN values
# Duplicate row with index [18727 20737 31678] was in group 5212 and was replaced with NaN values
# Duplicate row with index [13604 27195] was in group 5359 and was replaced with NaN values
# Duplicate row with index [11090 11738 16606 19288 27607 30054] was in group 5441 and was replaced with NaN values
# Duplicate row with index [ 6061 18649 32832] was in group 5466 and was replaced with NaN values
# Duplicate row with index [14757 21938] was in group 5467 and was replaced with NaN values
# Duplicate row with index [11842 12972 21468] was in group 5745 and was replaced with NaN values
# Duplicate row with index [11208 24719] was in group 5839 and was replaced with NaN values
# Duplicate row with index [ 7113 10155 11493] was in group 5875 and was replaced with NaN values
# Duplicate row with index [27515 33332] was in group 5944 and was replaced with NaN values
# Duplicate row with index [10917 21834 32162] was in group 6015 and was replaced with NaN values
# Duplicate row with index [11292 20202 25071 30171] was in group 6226 and was replaced with NaN values
# Duplicate row with index [ 8434 12247 23153 25543] was in group 6277 and was replaced with NaN values
# Duplicate row with index [7561 8340] was in group 6292 and was replaced with NaN values
# Duplicate row with index [ 8087 10395 34719] was in group 6405 and was replaced with NaN values
# Duplicate row with index [ 6902 16068 34851] was in group 6408 and was replaced with NaN values
# Duplicate row with index [ 7535 10087] was in group 6444 and was replaced with NaN values
# Duplicate row with index [10226 24933 34999] was in group 6446 and was replaced with NaN values
# Duplicate row with index [ 9519 10736 23955 27724 27944 28991] was in group 6491 and was replaced with NaN values
# Duplicate row with index [17311 23326] was in group 6527 and was replaced with NaN values
# Duplicate row with index [10691 28290 34983] was in group 6689 and was replaced with NaN values
# Duplicate row with index [27061 27181 34137] was in group 6718 and was replaced with NaN values
# Duplicate row with index [11001 25913] was in group 6728 and was replaced with NaN values
# Duplicate row with index [11719 15982 33480 35050] was in group 6872 and was replaced with NaN values
# Duplicate row with index [12428 24673] was in group 6874 and was replaced with NaN values
# Duplicate row with index [16990 29124] was in group 6906 and was replaced with NaN values
# Duplicate row with index [10558 25640] was in group 6964 and was replaced with NaN values
# Duplicate row with index [ 7245 28729] was in group 7029 and was replaced with NaN values
# Duplicate row with index [ 9682 27667] was in group 7085 and was replaced with NaN values
# Duplicate row with index [23396 26717 28971] was in group 7183 and was replaced with NaN values
# Duplicate row with index [24351 26436 29114] was in group 7246 and was replaced with NaN values
# Duplicate row with index [ 9500 24279 32664] was in group 7247 and was replaced with NaN values
# Duplicate row with index [10184 11973 15126 28723] was in group 7264 and was replaced with NaN values
# Duplicate row with index [11627 28150 35499] was in group 7296 and was replaced with NaN values
# Duplicate row with index [ 7791 18495 31363] was in group 7366 and was replaced with NaN values
# Duplicate row with index [20964 32537] was in group 7391 and was replaced with NaN values
# Duplicate row with index [19579 32219] was in group 7398 and was replaced with NaN values
# Duplicate row with index [29037 29503 31739] was in group 7414 and was replaced with NaN values
# Duplicate row with index [ 6055  7595 15846 18627 19058] was in group 7432 and was replaced with NaN values
# Duplicate row with index [ 7792 11717 22525 28289 30023 34948] was in group 7433 and was replaced with NaN values
# Duplicate row with index [ 7365 26078 26477] was in group 7517 and was replaced with NaN values
# Duplicate row with index [ 7315  9700 13228 33851] was in group 7559 and was replaced with NaN values
# Duplicate row with index [10082 12775 15850 34924] was in group 7601 and was replaced with NaN values
# Duplicate row with index [16932 28918] was in group 7644 and was replaced with NaN values
# Duplicate row with index [ 6155 17372 22532] was in group 7646 and was replaced with NaN values
# Duplicate row with index [15329 17289 32806 34548] was in group 7649 and was replaced with NaN values
# Duplicate row with index [18643 31933 32950] was in group 7653 and was replaced with NaN values
# Duplicate row with index [16899 33962] was in group 7677 and was replaced with NaN values
# Duplicate row with index [10577 31740 34252] was in group 7805 and was replaced with NaN values
# Duplicate row with index [15524 31743] was in group 7852 and was replaced with NaN values
# Duplicate row with index [19002 28483] was in group 7854 and was replaced with NaN values
# Duplicate row with index [11048 20046 21704 35202] was in group 7891 and was replaced with NaN values
# Duplicate row with index [13600 21693 22218 22272] was in group 7901 and was replaced with NaN values
# Duplicate row with index [ 9910 14755 25264 27211] was in group 7969 and was replaced with NaN values
# Duplicate row with index [ 6453 23119 23554] was in group 8065 and was replaced with NaN values
# Duplicate row with index [ 6334 24630] was in group 8153 and was replaced with NaN values
# Duplicate row with index [13736 18644 19844] was in group 8192 and was replaced with NaN values
# Duplicate row with index [12742 27120 31172 35097] was in group 8203 and was replaced with NaN values
# Duplicate row with index [ 8396 29842] was in group 8302 and was replaced with NaN values
# Duplicate row with index [21207 35402] was in group 8359 and was replaced with NaN values
# Duplicate row with index [12123 22823 24551 34107] was in group 8383 and was replaced with NaN values
# Duplicate row with index [11864 15195 21760] was in group 8409 and was replaced with NaN values
# Duplicate row with index [23108 31094 32962] was in group 8424 and was replaced with NaN values
# Duplicate row with index [ 9119  9506 29027] was in group 8444 and was replaced with NaN values
# Duplicate row with index [ 9925 21362 30890 34240] was in group 8468 and was replaced with NaN values
# Duplicate row with index [6073 8367] was in group 8504 and was replaced with NaN values
# Duplicate row with index [11565 21254] was in group 8514 and was replaced with NaN values
# Duplicate row with index [12333 23334] was in group 8530 and was replaced with NaN values
# Duplicate row with index [10754 20115 25156] was in group 8750 and was replaced with NaN values
# Duplicate row with index [12835 30179 32341] was in group 8842 and was replaced with NaN values
# Duplicate row with index [ 9836 14226 19960 22381 27001] was in group 8876 and was replaced with NaN values
# Duplicate row with index [10105 16561] was in group 8884 and was replaced with NaN values
# Duplicate row with index [15429 32301] was in group 8908 and was replaced with NaN values
# Duplicate row with index [13380 26744 26839 30143 34932] was in group 8910 and was replaced with NaN values
# Duplicate row with index [16620 20689 22650] was in group 8934 and was replaced with NaN values
# Duplicate row with index [ 5972 17672 28032] was in group 8949 and was replaced with NaN values
# Duplicate row with index [ 8029 27509 32989] was in group 8950 and was replaced with NaN values
# Duplicate row with index [15014 17537 24330 28408 30558 34527] was in group 9004 and was replaced with NaN values
# Duplicate row with index [14724 34921] was in group 9038 and was replaced with NaN values
# Duplicate row with index [11067 33937 34005] was in group 9045 and was replaced with NaN values
# Duplicate row with index [17858 26740] was in group 9077 and was replaced with NaN values
# Duplicate row with index [11633 31397] was in group 9096 and was replaced with NaN values
# Duplicate row with index [ 5968 11386 13711 17774 35068] was in group 9131 and was replaced with NaN values
# Duplicate row with index [ 9558 21525 22550 24411] was in group 9158 and was replaced with NaN values
# Duplicate row with index [ 6912 19418] was in group 9177 and was replaced with NaN values
# Duplicate row with index [11561 19388 30814] was in group 9193 and was replaced with NaN values
# Duplicate row with index [22665 30130 34153] was in group 9294 and was replaced with NaN values
# Duplicate row with index [10458 14315 20766] was in group 9297 and was replaced with NaN values
# Duplicate row with index [11457 21072 22737] was in group 9377 and was replaced with NaN values
# Duplicate row with index [16188 17628 23416] was in group 9386 and was replaced with NaN values
# Duplicate row with index [14280 22806] was in group 9418 and was replaced with NaN values
# Duplicate row with index [32675 35392] was in group 9449 and was replaced with NaN values
# Duplicate row with index [ 8747  9219 16470 27854 32916] was in group 9537 and was replaced with NaN values
# Duplicate row with index [ 7324 25647] was in group 9555 and was replaced with NaN values
# Duplicate row with index [14750 16826 34582] was in group 9568 and was replaced with NaN values
# Duplicate row with index [20894 26164] was in group 9573 and was replaced with NaN values
# Duplicate row with index [ 7238  8866 23131] was in group 9591 and was replaced with NaN values
# Duplicate row with index [18430 23033 28503] was in group 9658 and was replaced with NaN values
# Duplicate row with index [24070 29412 29701] was in group 9677 and was replaced with NaN values
# Duplicate row with index [ 5966 16613 21686] was in group 9691 and was replaced with NaN values
# Duplicate row with index [11594 26654] was in group 9708 and was replaced with NaN values
# Duplicate row with index [10430 28067 31852] was in group 9725 and was replaced with NaN values
# Duplicate row with index [22102 26580 31810] was in group 9804 and was replaced with NaN values
# Duplicate row with index [6056 7416] was in group 9807 and was replaced with NaN values
# Duplicate row with index [18846 29142] was in group 9827 and was replaced with NaN values
# Duplicate row with index [ 9212 33724] was in group 9828 and was replaced with NaN values
# Duplicate row with index [ 6070  7585 12716 23580] was in group 9929 and was replaced with NaN values
# Duplicate row with index [ 9042 13697 35509] was in group 9944 and was replaced with NaN values
# Duplicate row with index [ 7362 23944 27449] was in group 10007 and was replaced with NaN values
# Duplicate row with index [10859 23301 30649 35236] was in group 10041 and was replaced with NaN values
# Duplicate row with index [12261 22334 22934 29709] was in group 10042 and was replaced with NaN values
# Duplicate row with index [ 5965 16595 19959 27087 30032 32440] was in group 10069 and was replaced with NaN values
# Duplicate row with index [ 7262 15247 29524] was in group 10088 and was replaced with NaN values
# Duplicate row with index [15954 24275 25868 28961 33431] was in group 10133 and was replaced with NaN values
# Duplicate row with index [ 6336 21578 29506] was in group 10188 and was replaced with NaN values
# Duplicate row with index [ 8592 14441 33008] was in group 10219 and was replaced with NaN values
# Duplicate row with index [12194 13153] was in group 10249 and was replaced with NaN values
# Duplicate row with index [11988 23027 27905] was in group 10261 and was replaced with NaN values
# Duplicate row with index [ 8032  8947  9441 14202 27546 30750 32542 33623 34307] was in group 10268 and was replaced with NaN values
# Duplicate row with index [13806 15972 16257 16712 22560 27448 34705] was in group 10282 and was replaced with NaN values
# Duplicate row with index [18136 19216 35351] was in group 10294 and was replaced with NaN values
# Duplicate row with index [ 9753 32850] was in group 10400 and was replaced with NaN values
# Duplicate row with index [ 5898  6519 19487 22572] was in group 10403 and was replaced with NaN values
# Duplicate row with index [20309 29887] was in group 10408 and was replaced with NaN values
# Duplicate row with index [20648 22176] was in group 10437 and was replaced with NaN values
# Duplicate row with index [ 9722 11783] was in group 10445 and was replaced with NaN values
# Duplicate row with index [11930 29638 31278 34323] was in group 10506 and was replaced with NaN values
# Duplicate row with index [ 7261  9735 23196 30193] was in group 10507 and was replaced with NaN values
# Duplicate row with index [ 7620  7702 16056 32678 34602] was in group 10530 and was replaced with NaN values
# Duplicate row with index [14375 14403 22842 30984 31358] was in group 10563 and was replaced with NaN values
# Duplicate row with index [10778 11016 34876] was in group 10597 and was replaced with NaN values
# Duplicate row with index [ 8275 27536] was in group 10607 and was replaced with NaN values
# Duplicate row with index [12345 12712] was in group 10640 and was replaced with NaN values
# Duplicate row with index [13009 26393] was in group 10653 and was replaced with NaN values
# Duplicate row with index [14903 27455] was in group 10659 and was replaced with NaN values
# Duplicate row with index [11925 33680 35181] was in group 10670 and was replaced with NaN values
# Duplicate row with index [ 9874 12296 17839 19521 21625 34920] was in group 10679 and was replaced with NaN values
# Duplicate row with index [14936 24790] was in group 10682 and was replaced with NaN values
# Duplicate row with index [ 7257 18904 29988] was in group 10685 and was replaced with NaN values
# Duplicate row with index [12041 22313] was in group 10697 and was replaced with NaN values
# Duplicate row with index [13586 14700 20365 21271 25926] was in group 10702 and was replaced with NaN values
# Duplicate row with index [18053 20720] was in group 10709 and was replaced with NaN values
# Duplicate row with index [ 6999 19821 34844] was in group 10744 and was replaced with NaN values
# Duplicate row with index [ 8544 21916 30739] was in group 10821 and was replaced with NaN values
# Duplicate row with index [ 7802 10658 13965 15934] was in group 10828 and was replaced with NaN values
# Duplicate row with index [ 5758 27938 28373 30349] was in group 10838 and was replaced with NaN values
# Duplicate row with index [16686 32700] was in group 10853 and was replaced with NaN values
# Duplicate row with index [21764 23375 23386 23842 24908] was in group 10858 and was replaced with NaN values
# Duplicate row with index [14943 16063 16762 19624 25277 35238] was in group 10875 and was replaced with NaN values
# Duplicate row with index [10693 13514 18113 30442 31075] was in group 10898 and was replaced with NaN values
# Duplicate row with index [10787 14562] was in group 10912 and was replaced with NaN values
# Duplicate row with index [ 6185 14673 23518 26599 27552 33589] was in group 10931 and was replaced with NaN values
# Duplicate row with index [ 8643 14087 18453 29329] was in group 10941 and was replaced with NaN values
# Duplicate row with index [10233 27307] was in group 10942 and was replaced with NaN values
# Duplicate row with index [ 7250  8786 10525 14880 16767 25692] was in group 10967 and was replaced with NaN values
# Duplicate row with index [ 8689 18767] was in group 10968 and was replaced with NaN values
# Duplicate row with index [10311 23309] was in group 10984 and was replaced with NaN values
# Duplicate row with index [16047 32235] was in group 10993 and was replaced with NaN values
# Duplicate row with index [19980 23479 31975] was in group 11017 and was replaced with NaN values
# Duplicate row with index [16979 23279 23559 29612] was in group 11121 and was replaced with NaN values
# Duplicate row with index [17185 25121] was in group 11160 and was replaced with NaN values
# Duplicate row with index [11464 13411 28551 30968 33726] was in group 11276 and was replaced with NaN values
# Duplicate row with index [18865 19097] was in group 11350 and was replaced with NaN values
# Duplicate row with index [17437 19924 28988] was in group 11369 and was replaced with NaN values
# Duplicate row with index [35141 35389] was in group 11431 and was replaced with NaN values
# Duplicate row with index [18961 22208 32784] was in group 11451 and was replaced with NaN values
# Duplicate row with index [17087 17921 21112 33422] was in group 11639 and was replaced with NaN values
# Duplicate row with index [17576 27521 30873] was in group 11649 and was replaced with NaN values
# Duplicate row with index [14144 16211 19801 29373 34277] was in group 11650 and was replaced with NaN values
# Duplicate row with index [17299 31912] was in group 11794 and was replaced with NaN values
# Duplicate row with index [21624 32466] was in group 11795 and was replaced with NaN values
# Duplicate row with index [ 7389 19880 34899] was in group 11811 and was replaced with NaN values
# Duplicate row with index [30866 32113] was in group 11862 and was replaced with NaN values
# Duplicate row with index [20726 21450 24022 29594] was in group 11872 and was replaced with NaN values
# (35566,)
# (35566,)
# Number of rows in features before: 35566
# Number of rows in features after: 11543
# Number of rows in labels: 11543
# Number of rows in lats: 11543
# Number of rows in lons: 11543

# %%
features = np.load("preprocessed/features_CS_secondhalf_84_1.npy")
labels = np.load("preprocessed/labels_CS_secondhalf_84_1.npy")

# %%
features.shape
# Out:
# (11543, 139)

# %%
features = torch.tensor(features)
labels = torch.tensor(labels)

# %%
trainloader, testloader = create_train_test_loader(features, labels, batch_size = 200, test_size_ratio=1/7, shuffle=True)
# Out:
# Train data size
# 9894
# Test data size
# 1649

# %%
"""
print(f"Model structure: {model}\n\n")

for name, param in model.named_parameters():
    print(f"Layer: {name} | Size: {param.size()} | Values : {param[:2]} \n")
"""
# Out:
# '\nprint(f"Model structure: {model}\n\n")\n\nfor name, param in model.named_parameters():\n    print(f"Layer: {name} | Size: {param.size()} | Values : {param[:2]} \n")\n'

# %%
# if there is a pretrained model, this can be used
"""
path = Path().resolve().parents[1] / "models" / "supervisedmodel_TOC_noconstraint_CS.pth"
state_dict = torch.load(path)
model.load_state_dict(state_dict)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu') #'cuda:0' if torch.cuda.is_available() else 
#print(physical_devices)
model.to(device)
model.double()
"""
# Out:
# '\npath = Path().resolve().parents[1] / "models" / "supervisedmodel_TOC_noconstraint_CS.pth"\nstate_dict = torch.load(path)\nmodel.load_state_dict(state_dict)\ndevice = torch.device(\'cuda:0\' if torch.cuda.is_available() else \'cpu\') #\'cuda:0\' if torch.cuda.is_available() else \n#print(physical_devices)\nmodel.to(device)\nmodel.double()\n'

# %%
# GPU intensive operation!!
num_epochs = 500
training_accuracy, training_losses, training_mae, learning_rate, evaluation_losses, evaluation_mae, true_labels, pred_labels =  train_model(model, loss_fn, trainloader, testloader, num_epochs = num_epochs)
# Out:
# epoch: 0 | Training Loss: 1.816 | MAE: 0.494 | LR: 0.0100000 |
# epoch: 0 | Testing Loss: 0.276 | MAE: 0.252  |
#
# epoch: 1 | Training Loss: 0.553 | MAE: 0.319 | LR: 0.0100000 |
# epoch: 1 | Testing Loss: 0.303 | MAE: 0.237  |
#
# epoch: 2 | Training Loss: 0.556 | MAE: 0.299 | LR: 0.0100000 |
# epoch: 2 | Testing Loss: 0.688 | MAE: 0.294  |
#
# epoch: 3 | Training Loss: 0.539 | MAE: 0.282 | LR: 0.0080000 |
# epoch: 3 | Testing Loss: 0.220 | MAE: 0.204  |
#
# epoch: 4 | Training Loss: 0.441 | MAE: 0.263 | LR: 0.0080000 |
# epoch: 4 | Testing Loss: 0.241 | MAE: 0.221  |
#
# epoch: 5 | Training Loss: 0.421 | MAE: 0.260 | LR: 0.0064000 |
# epoch: 5 | Testing Loss: 0.378 | MAE: 0.230  |
#
# epoch: 6 | Training Loss: 0.423 | MAE: 0.253 | LR: 0.0064000 |
# epoch: 6 | Testing Loss: 0.259 | MAE: 0.205  |
#
# epoch: 7 | Training Loss: 0.393 | MAE: 0.245 | LR: 0.0064000 |
# epoch: 7 | Testing Loss: 0.224 | MAE: 0.187  |
#
# epoch: 8 | Training Loss: 0.389 | MAE: 0.244 | LR: 0.0051200 |
# epoch: 8 | Testing Loss: 0.264 | MAE: 0.205  |
#
# epoch: 9 | Training Loss: 0.358 | MAE: 0.229 | LR: 0.0040960 |
# epoch: 9 | Testing Loss: 0.349 | MAE: 0.224  |
#
# epoch: 10 | Training Loss: 0.351 | MAE: 0.231 | LR: 0.0032768 |
# epoch: 10 | Testing Loss: 0.195 | MAE: 0.185  |
#
# epoch: 11 | Training Loss: 0.363 | MAE: 0.230 | LR: 0.0032768 |
# epoch: 11 | Testing Loss: 0.258 | MAE: 0.210  |
#
# epoch: 12 | Training Loss: 0.311 | MAE: 0.223 | LR: 0.0026214 |
# epoch: 12 | Testing Loss: 0.199 | MAE: 0.180  |
#
# epoch: 13 | Training Loss: 0.308 | MAE: 0.216 | LR: 0.0020972 |
# epoch: 13 | Testing Loss: 0.200 | MAE: 0.179  |
#
# epoch: 14 | Training Loss: 0.360 | MAE: 0.225 | LR: 0.0016777 |
# epoch: 14 | Testing Loss: 0.201 | MAE: 0.180  |
#
# epoch: 15 | Training Loss: 0.310 | MAE: 0.216 | LR: 0.0013422 |
# epoch: 15 | Testing Loss: 0.194 | MAE: 0.173  |
| MAE: 0.193 | LR: 0.0000100 |
# epoch: 484 | Testing Loss: 0.197 | MAE: 0.158  |
#
# epoch: 485 | Training Loss: 0.239 | MAE: 0.196 | LR: 0.0000100 |
# epoch: 485 | Testing Loss: 0.216 | MAE: 0.172  |
#
# epoch: 486 | Training Loss: 0.245 | MAE: 0.191 | LR: 0.0000100 |
# epoch: 486 | Testing Loss: 0.194 | MAE: 0.161  |
#
# epoch: 487 | Training Loss: 0.231 | MAE: 0.190 | LR: 0.0000100 |
# epoch: 487 | Testing Loss: 0.192 | MAE: 0.158  |
#
# epoch: 488 | Training Loss: 0.241 | MAE: 0.195 | LR: 0.0000100 |
# epoch: 488 | Testing Loss: 0.200 | MAE: 0.163  |
#
# epoch: 489 | Training Loss: 0.247 | MAE: 0.195 | LR: 0.0000100 |
# epoch: 489 | Testing Loss: 0.194 | MAE: 0.161  |
#
# epoch: 490 | Training Loss: 0.244 | MAE: 0.193 | LR: 0.0000100 |
# epoch: 490 | Testing Loss: 0.187 | MAE: 0.160  |
#
# epoch: 491 | Training Loss: 0.260 | MAE: 0.196 | LR: 0.0000100 |
# epoch: 491 | Testing Loss: 0.191 | MAE: 0.156  |
#
# epoch: 492 | Training Loss: 0.230 | MAE: 0.193 | LR: 0.0000100 |
# epoch: 492 | Testing Loss: 0.200 | MAE: 0.155  |
#
# epoch: 493 | Training Loss: 0.222 | MAE: 0.192 | LR: 0.0000100 |
# epoch: 493 | Testing Loss: 0.187 | MAE: 0.155  |
#
# epoch: 494 | Training Loss: 0.230 | MAE: 0.190 | LR: 0.0000100 |
# epoch: 494 | Testing Loss: 0.245 | MAE: 0.168  |
#
# epoch: 495 | Training Loss: 0.228 | MAE: 0.195 | LR: 0.0000100 |
# epoch: 495 | Testing Loss: 0.200 | MAE: 0.156  |
#
# epoch: 496 | Training Loss: 0.240 | MAE: 0.194 | LR: 0.0000100 |
# epoch: 496 | Testing Loss: 0.233 | MAE: 0.169  |
#
# epoch: 497 | Training Loss: 0.222 | MAE: 0.192 | LR: 0.0000100 |
# epoch: 497 | Testing Loss: 0.190 | MAE: 0.159  |
#
# epoch: 498 | Training Loss: 0.225 | MAE: 0.189 | LR: 0.0000100 |
# epoch: 498 | Testing Loss: 0.190 | MAE: 0.155  |
#
# epoch: 499 | Training Loss: 0.220 | MAE: 0.195 | LR: 0.0000100 |
# epoch: 499 | Testing Loss: 0.189 | MAE: 0.159  |

# %%
torch.manual_seed(42)
plot_model_performance(num_epochs, evaluation_losses, training_losses, learning_rate)

# %%
output_path = Path().resolve().parents[1] / "data" / "output" / "scatterplots_TOC" / "scatter_plot_TOC_CS_men_secondhalf_84_1.png"
output_path = str(output_path)
test_labels, test_targets = evaluate_model(model, testloader, output_path)
# Out:
# (1649,)
# (1649,)
# correlation coefficient:
# 0.8384402711602631
# mae:
# 0.16135897272998162
# mse:
# 0.20142703653101438
# rmse:
# 0.4488062349511361

# %%
#lats = np.load("lats_CS.npy")
#lons = np.load("lons_CS.npy")
all_labels, all_targets =  evaluate_all_predictions(model, features, labels, output_path)
# Out:
# correlation coefficient:
# 0.9001994426329054
# mae:
# 0.15529340277301182
# mse:
# 0.17589229304978823
# rmse:
# 0.4193951514381017

# %%
# Scatter plot with different colors for test labels and test targets
plt.scatter(all_labels, all_targets, label='All Data', s= 7)
plt.scatter(test_labels, test_targets, label='Test Data', color='brown', s=7)  # Add this line

line = np.linspace(0, 10, 100)

# Plot the reference line
plt.plot(line, line, 'orange')

# Set labels and title
plt.xlabel("Labels")
plt.ylabel("Outputs")

# Add legend
plt.legend()

# %%
#torch.save(model.state_dict(), path = Path().resolve().parents[1] / "models" / "supervisedmodel_TOC_noconstrCS.pth")

# %%
#"""
np.save("all_labels_NN_CS_secondhalf_84_1", all_labels)
np.save("all_predictions_NN_CS_secondhalf_84_1", all_targets)
np.save("test_labels_NN_CS_secondhalf_84_1", test_labels)
np.save("test_predictions_NN_CS_secondhalf_84_1", test_targets)
#"""

# %% [markdown]
# ### Explain DNN using SHAP values (Find feature importance)

# %%
#should shuffle the indices again
features = np.load("preprocessed/features_CS.npy")
labels = np.load("preprocessed/labels_CS.npy")

import shap
import pandas as pd

# Convert the input features to a PyTorch tensor with the correct data type
features = torch.tensor(features, dtype=torch.float64)

if torch.cuda.is_available():
    features = features.cuda()

# %%
# GPU intensive operation!!!
explain_shap(model, features, feature_names=None, explainer_path='preprocessed/explainer_CS.pkl', shap_values_path='preprocessed/shap_values_CS.pkl', force_plot_index=0, summary_max_display=10)

#if the previous line has already been performed and the shap values are saved, only the following lines can be used.
with open('preprocessed/explainer_CS.pkl', 'rb') as explainer_file:
    explainer = pickle.load(explainer_file)

with open('preprocessed/shap_values_CS.pkl', 'rb') as shap_values_file:
    shap_values = pickle.load(shap_values_file)
# Out:
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# ### Predict using the trained DNN

# %%
import torch
from pathlib import Path
import pickle
import numpy as np
from matplotlib import pyplot as plt
import os
import gc
from os import walk  


feature_path = path = Path().resolve().parents[1] / "data" / "interim" / "inputfeatures" / "SedTOCFeaturesnoNAN_TOC_CS_men_secondhalf_84_1"
X_mean = np.load(Path(feature_path / "features_mean.npy")).astype(float)
X_std = np.load(Path(feature_path / "features_std.npy")).astype(float)

dataset_path = Path().resolve().parents[1] / "data" / "interim" / "worldfeatures" / "WorldFeaturesAllnoNaN_SedTOC"

files = []

for (dirpath, dirnames, filenames) in walk(dataset_path):
    files.extend(filenames)
    break

files.sort()


features = np.load(Path(dataset_path / files[0]))
prediction_sum_save = Path().resolve().parents[1] / "data" / "interim" / "predictions" / "predictions_CS_secondhalf_84_1"

# %%
model.eval()
enable_dropout(model) #for mc dropout


np.random.seed(42)
torch.manual_seed(42)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu') #'cuda:0' if torch.cuda.is_available() else 
#print(physical_devices)
model.to(device)
model.double()
# Out:
# DNN(
#   (encoder): Sequential(
#     (0): Linear(in_features=139, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Linear(in_features=512, out_features=512, bias=True)
#     (9): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Linear(in_features=512, out_features=512, bias=True)
#     (13): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): Dropout(p=0.2, inplace=False)
#     (16): Linear(in_features=512, out_features=512, bias=True)
#     (17): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU()
#     (19): Dropout(p=0.2, inplace=False)
#     (20): Linear(in_features=512, out_features=512, bias=True)
#     (21): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU()
#     (23): Dropout(p=0.2, inplace=False)
#     (24): Linear(in_features=512, out_features=512, bias=True)
#     (25): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU()
#     (27): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=512, out_features=512, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Linear(in_features=512, out_features=512, bias=True)
#     (10): ReLU()
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Linear(in_features=512, out_features=512, bias=True)
#     (13): ReLU()
#     (14): Dropout(p=0.2, inplace=False)
#     (15): Linear(in_features=512, out_features=512, bias=True)
#     (16): ReLU()
#     (17): Dropout(p=0.2, inplace=False)
#     (18): Linear(in_features=512, out_features=139, bias=True)
#   )
#   (supervised): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Linear(in_features=512, out_features=512, bias=True)
#     (9): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Linear(in_features=512, out_features=1, bias=True)
#   )
# )

# %%
features = np.load(Path(dataset_path / files[0]))

chunk_shape = [6,4320] #360 chunks


first_run = True
ii = 0

for count, file in enumerate(files):
    #if count > 2:
    #    break
    features = np.load(Path(dataset_path / file))
    features = np.divide((features - X_mean), X_std)

    features = torch.tensor(features)
    features = features.to(device)

    # Perform multiple forward passes with dropout
    num_samples = 100  # number of monte carlo forward passes: gives us the number of predictions or the size of the prediction ensemble
    predictions_sum = np.zeros((num_samples, chunk_shape[0], chunk_shape[1]))

    with torch.no_grad():
        for i in range(num_samples):
            predictions = model(features)
         
            # Store predictions for later averaging
            predictions_sum[i] = predictions.cpu().detach().numpy().reshape(chunk_shape)

    # Average predictions over all samples
    predictions_avg = np.mean(predictions_sum, axis=0)
    predictions_var = np.var(predictions_sum, axis=0)
    save_path = os.path.join(prediction_sum_save , f'predictions_sum_{ii}.npy')
    np.save(save_path, predictions_sum)
    #fit_params, failed_fits, failed_fit_details = fit_gaussian_to_predictions(predictions_sum)
    #print(failed_fits)

    if first_run:
        prediction_map2 = predictions_avg
        prediction_map2_var = predictions_var
        first_run = False
    else:
        prediction_map2 = np.append(prediction_map2, predictions_avg, axis=0)
        prediction_map2_var = np.append(prediction_map2_var, predictions_var, axis=0)

    ii += 1
    print("Prediction " + str(ii) + " done!")

    del features
    gc.collect()
# Out:
# Prediction 1 done!
# Prediction 2 done!
# Prediction 3 done!
# Prediction 4 done!
# Prediction 5 done!
# Prediction 6 done!
# Prediction 7 done!
# Prediction 8 done!
# Prediction 9 done!
# Prediction 10 done!
# Prediction 11 done!
# Prediction 12 done!
# Prediction 13 done!
# Prediction 14 done!
# Prediction 15 done!
# Prediction 16 done!
# Prediction 17 done!
# Prediction 18 done!
# Prediction 19 done!
# Prediction 20 done!
# Prediction 21 done!
# Prediction 22 done!
# Prediction 23 done!
# Prediction 24 done!
# Prediction 25 done!
# Prediction 26 done!
# Prediction 27 done!
# Prediction 28 done!
# Prediction 29 done!
# Prediction 30 done!
# Prediction 31 done!
# Prediction 32 done!
# Prediction 33 done!
# Prediction 34 done!
# Prediction 35 done!
# Prediction 36 done!
# Prediction 37 done!
# Prediction 38 done!
# Prediction 39 done!
# Prediction 40 done!
# Prediction 41 done!
# Prediction 42 done!
# Prediction 43 done!
# Prediction 44 done!
# Prediction 45 done!
# Prediction 46 done!
# Prediction 47 done!
# Prediction 48 done!
# Prediction 49 done!
# Prediction 50 done!
# Prediction 51 done!
# Prediction 52 done!
# Prediction 53 done!
# Prediction 54 done!
# Prediction 55 done!
# Prediction 56 done!
# Prediction 57 done!
# Prediction 58 done!
# Prediction 59 done!
# Prediction 60 done!
# Prediction 61 done!
# Prediction 62 done!
# Prediction 63 done!
# Prediction 64 done!
# Prediction 65 done!
# Prediction 66 done!
# Prediction 67 done!
# Prediction 68 done!
# Prediction 69 done!
# Prediction 70 done!
# Prediction 71 done!
# Prediction 72 done!
# Prediction 73 done!
# Prediction 74 done!
# Prediction 75 done!
# Prediction 76 done!
# Prediction 77 done!
# Prediction 78 done!
# Prediction 79 done!
# Prediction 80 done!
# Prediction 81 done!
# Prediction 82 done!
# Prediction 83 done!
# Prediction 84 done!
# Prediction 85 done!
# Prediction 86 done!
# Prediction 87 done!
# Prediction 88 done!
# Prediction 89 done!
# Prediction 90 done!
# Prediction 91 done!
# Prediction 92 done!
# Prediction 93 done!
# Prediction 94 done!
# Prediction 95 done!
# Prediction 96 done!
# Prediction 97 done!
# Prediction 98 done!
# Prediction 99 done!
# Prediction 100 done!
# Prediction 101 done!
# Prediction 102 done!
# Prediction 103 done!
# Prediction 104 done!
# Prediction 105 done!
# Prediction 106 done!
# Prediction 107 done!
# Prediction 108 done!
# Prediction 109 done!
# Prediction 110 done!
# Prediction 111 done!
# Prediction 112 done!
# Prediction 113 done!
# Prediction 114 done!
# Prediction 115 done!
# Prediction 116 done!
# Prediction 117 done!
# Prediction 118 done!
# Prediction 119 done!
# Prediction 120 done!
# Prediction 121 done!
# Prediction 122 done!
# Prediction 123 done!
# Prediction 124 done!
# Prediction 125 done!
# Prediction 126 done!
# Prediction 127 done!
# Prediction 128 done!
# Prediction 129 done!
# Prediction 130 done!
# Prediction 131 done!
# Prediction 132 done!
# Prediction 133 done!
# Prediction 134 done!
# Prediction 135 done!
# Prediction 136 done!
# Prediction 137 done!
# Prediction 138 done!
# Prediction 139 done!
# Prediction 140 done!
# Prediction 141 done!
# Prediction 142 done!
# Prediction 143 done!
# Prediction 144 done!
# Prediction 145 done!
# Prediction 146 done!
# Prediction 147 done!
# Prediction 148 done!
# Prediction 149 done!
# Prediction 150 done!
# Prediction 151 done!
# Prediction 152 done!
# Prediction 153 done!
# Prediction 154 done!
# Prediction 155 done!
# Prediction 156 done!
# Prediction 157 done!
# Prediction 158 done!
# Prediction 159 done!
# Prediction 160 done!
# Prediction 161 done!
# Prediction 162 done!
# Prediction 163 done!
# Prediction 164 done!
# Prediction 165 done!
# Prediction 166 done!
# Prediction 167 done!
# Prediction 168 done!
# Prediction 169 done!
# Prediction 170 done!
# Prediction 171 done!
# Prediction 172 done!
# Prediction 173 done!
# Prediction 174 done!
# Prediction 175 done!
# Prediction 176 done!
# Prediction 177 done!
# Prediction 178 done!
# Prediction 179 done!
# Prediction 180 done!
# Prediction 181 done!
# Prediction 182 done!
# Prediction 183 done!
# Prediction 184 done!
# Prediction 185 done!
# Prediction 186 done!
# Prediction 187 done!
# Prediction 188 done!
# Prediction 189 done!
# Prediction 190 done!
# Prediction 191 done!
# Prediction 192 done!
# Prediction 193 done!
# Prediction 194 done!
# Prediction 195 done!
# Prediction 196 done!
# Prediction 197 done!
# Prediction 198 done!
# Prediction 199 done!
# Prediction 200 done!
# Prediction 201 done!
# Prediction 202 done!
# Prediction 203 done!
# Prediction 204 done!
# Prediction 205 done!
# Prediction 206 done!
# Prediction 207 done!
# Prediction 208 done!
# Prediction 209 done!
# Prediction 210 done!
# Prediction 211 done!
# Prediction 212 done!
# Prediction 213 done!
# Prediction 214 done!
# Prediction 215 done!
# Prediction 216 done!
# Prediction 217 done!
# Prediction 218 done!
# Prediction 219 done!
# Prediction 220 done!
# Prediction 221 done!
# Prediction 222 done!
# Prediction 223 done!
# Prediction 224 done!
# Prediction 225 done!
# Prediction 226 done!
# Prediction 227 done!
# Prediction 228 done!
# Prediction 229 done!
# Prediction 230 done!
# Prediction 231 done!
# Prediction 232 done!
# Prediction 233 done!
# Prediction 234 done!
# Prediction 235 done!
# Prediction 236 done!
# Prediction 237 done!
# Prediction 238 done!
# Prediction 239 done!
# Prediction 240 done!
# Prediction 241 done!
# Prediction 242 done!
# Prediction 243 done!
# Prediction 244 done!
# Prediction 245 done!
# Prediction 246 done!
# Prediction 247 done!
# Prediction 248 done!
# Prediction 249 done!
# Prediction 250 done!
# Prediction 251 done!
# Prediction 252 done!
# Prediction 253 done!
# Prediction 254 done!
# Prediction 255 done!
# Prediction 256 done!
# Prediction 257 done!
# Prediction 258 done!
# Prediction 259 done!
# Prediction 260 done!
# Prediction 261 done!
# Prediction 262 done!
# Prediction 263 done!
# Prediction 264 done!
# Prediction 265 done!
# Prediction 266 done!
# Prediction 267 done!
# Prediction 268 done!
# Prediction 269 done!
# Prediction 270 done!
# Prediction 271 done!
# Prediction 272 done!
# Prediction 273 done!
# Prediction 274 done!
# Prediction 275 done!
# Prediction 276 done!
# Prediction 277 done!
# Prediction 278 done!
# Prediction 279 done!
# Prediction 280 done!
# Prediction 281 done!
# Prediction 282 done!
# Prediction 283 done!
# Prediction 284 done!
# Prediction 285 done!
# Prediction 286 done!
# Prediction 287 done!
# Prediction 288 done!
# Prediction 289 done!
# Prediction 290 done!
# Prediction 291 done!
# Prediction 292 done!
# Prediction 293 done!
# Prediction 294 done!
# Prediction 295 done!
# Prediction 296 done!
# Prediction 297 done!
# Prediction 298 done!
# Prediction 299 done!
# Prediction 300 done!
# Prediction 301 done!
# Prediction 302 done!
# Prediction 303 done!
# Prediction 304 done!
# Prediction 305 done!
# Prediction 306 done!
# Prediction 307 done!
# Prediction 308 done!
# Prediction 309 done!
# Prediction 310 done!
# Prediction 311 done!
# Prediction 312 done!
# Prediction 313 done!
# Prediction 314 done!
# Prediction 315 done!
# Prediction 316 done!
# Prediction 317 done!
# Prediction 318 done!
# Prediction 319 done!
# Prediction 320 done!
# Prediction 321 done!
# Prediction 322 done!
# Prediction 323 done!
# Prediction 324 done!
# Prediction 325 done!
# Prediction 326 done!
# Prediction 327 done!
# Prediction 328 done!
# Prediction 329 done!
# Prediction 330 done!
# Prediction 331 done!
# Prediction 332 done!
# Prediction 333 done!
# Prediction 334 done!
# Prediction 335 done!
# Prediction 336 done!
# Prediction 337 done!
# Prediction 338 done!
# Prediction 339 done!
# Prediction 340 done!
# Prediction 341 done!
# Prediction 342 done!
# Prediction 343 done!
# Prediction 344 done!
# Prediction 345 done!
# Prediction 346 done!
# Prediction 347 done!
# Prediction 348 done!
# Prediction 349 done!
# Prediction 350 done!
# Prediction 351 done!
# Prediction 352 done!
# Prediction 353 done!
# Prediction 354 done!
# Prediction 355 done!
# Prediction 356 done!
# Prediction 357 done!
# Prediction 358 done!
# Prediction 359 done!
# Prediction 360 done!

# %%
### GPU intensive operation!!
#prediction_map2, prediction_map2_var = perform_mc_dropout_prediction(model, dataset_path, prediction_sum_save, X_mean, X_std)

# %%
# We save the distributions or the monte carlo output for each chunk. Here we read all the distributions from different chunks and paste it together.
# Reading the distributions of all the chunks requires a lot of memory!!
# Requires high memory(RAM)(atleast 65 GB of RAM). Should probably be run on a CPU(prefereable a cluster) to get all the prediction distributions.
# UNCOMMENT IT TO PUT THE CHUNKS OF THE DISTRIBUTIONS TOGETHER
"""
import os
import numpy as np

# Get a list of files in the directory and sort them
files_in_dir = sorted([f for f in os.listdir(prediction_sum_save) if f.endswith('.npy')], key=lambda x: int(x.split('_')[-1][:-4]))


failed_fits_all = []
i = 0
first_run = True

# Load and concatenate each predictions_sum array along the second axis
for file in files_in_dir:
    file_path = os.path.join(prediction_sum_save, file)
    predictions_sum = np.load(file_path)
    
    if first_run:
        prediction_map_dist = predictions_sum
        first_run = False
    else:
        # Concatenate along the second axis (axis=1)
        prediction_map_dist = np.concatenate((prediction_map_dist, predictions_sum), axis=1)
    i += 1
    print(i)
np.save(Path().resolve().parents[1] / "data" / "output" / "predictionmaps_TOC" / "prediction_map_dist_CS_secondhalf_84_1", prediction_map_dist)
"""
# Out:
# '\nimport os\nimport numpy as np\n\n# Get a list of files in the directory and sort them\nfiles_in_dir = sorted([f for f in os.listdir(prediction_sum_save) if f.endswith(\'.npy\')], key=lambda x: int(x.split(\'_\')[-1][:-4]))\n\n\nfailed_fits_all = []\ni = 0\nfirst_run = True\n\n# Load and concatenate each predictions_sum array along the second axis\nfor file in files_in_dir:\n    file_path = os.path.join(prediction_sum_save, file)\n    predictions_sum = np.load(file_path)\n    \n    if first_run:\n        prediction_map_dist = predictions_sum\n        first_run = False\n    else:\n        # Concatenate along the second axis (axis=1)\n        prediction_map_dist = np.concatenate((prediction_map_dist, predictions_sum), axis=1)\n    i += 1\n    print(i)\nnp.save(Path().resolve().parents[1] / "data" / "output" / "predictionmaps_TOC" / "prediction_map_dist_CS_secondhalf_84_1", prediction_map_dist)\n'

# %%
land_file = path = Path().resolve().parents[1] / "data" / "raw" / "island_map.npy"
land_map = np.load(land_file)
land_map[np.isnan(land_map)] = 1

# %%
import matplotlib.colors as mcolors
prediction_map2 = np.rot90(np.rot90(np.fliplr(prediction_map2)))
#prediction_map2[land_map] = 0

# %%
plt.imshow(land_map)

# %%
prediction_map2[land_map] = 0
plt.figure(figsize=[25, 15], dpi=50)
plt.imshow(prediction_map2, norm=mcolors.LogNorm(vmin=1e-1, vmax=15),cmap="cubehelix")
cbar = plt.colorbar()

# %%
np.save( Path().resolve().parents[1] / "data" / "output" / "predictionmaps_TOC" / "prediction_map_TOC_supervised_men_CS_secondhalf_84_1", prediction_map2)
