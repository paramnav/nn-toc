# %% [markdown]
# ### K Nearest Neighbours

# %%
from pathlib import Path
import pickle
import numpy as np
from matplotlib import pyplot as plt
#from sklearn.model_selection import StratifiedKFold, KFold
#from sklearn.model_selection import train_test_split
import os

np.random.seed(42)

# %%
feature_path = Path().resolve().parents[1] / "data" / "interim" / "inputfeatures" / "SedTOCFeaturesnoNAN_TOC_DO_men"
features = np.load(Path(feature_path / "numpy_features.npy"))
labels = np.load(Path(feature_path / "numpy_labels.npy"))
X_mean = np.load(Path(feature_path / "features_mean.npy")).astype(float)
X_std = np.load(Path(feature_path / "features_std.npy")).astype(float)

# %%
"""
#time intensive operation(better save processed features and labels, after first run)
features, labels = preprocess_features_labels(features, labels, X_mean, X_std) 
np.save("preprocessed/features_CS", features)
np.save("preprocessed/labels_CS", labels)
"""
# Out:
# '\n#time intensive operation(better save processed features and labels, after first run)\nfeatures, labels = preprocess_features_labels(features, labels, X_mean, X_std) \nnp.save("preprocessed/features_CS", features)\nnp.save("preprocessed/labels_CS", labels)\n'

# %%
features = np.load("preprocessed/features_DO.npy")
labels = np.load("preprocessed/labels_DO.npy")

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
from torch.utils.data import DataLoader, TensorDataset

# Assuming you already have features and labels loaded

# Convert tensors to numpy arrays
features_np = features
labels_np = labels

# Reshape the features to (num_samples, num_channels) if needed
features_np = features_np.reshape(features_np.shape[0], -1)

test_size=int(features.shape[0]/7)
train_size=features.shape[0]-test_size

# Split the data into training and testing sets
#test_size = 0.2  # You can adjust this percentage based on your needs
features_train, features_test, labels_train, labels_test = train_test_split(
    features_np, labels_np, test_size=test_size, random_state=42
)

for i in range(9):
    print(i)
    # Initialize KNN regressor with 5 neighbors
    knn_regressor = KNeighborsRegressor(n_neighbors=i+1)

    # Train the model on the training set
    knn_regressor.fit(features_train, labels_train)

    # Predict on the test set
    test_predictions = knn_regressor.predict(features_test)
    all_predictions = knn_regressor.predict(features_np)

    # Calculate the correlation coefficient for test data
    corr_test, _ = pearsonr(labels_test, test_predictions)
    print(f"Correlation coefficient on test data: {corr_test}")
    corr_all, _ = pearsonr(labels_np, all_predictions)
    print(f"Correlation coefficient on all data: {corr_all}")
    # Create a scatter plot for both test and all data
    plt.figure()
    plt.scatter(labels_np, all_predictions, c="blue", label=f'All Data (Corr: {corr_all:.2f})', s= 10)
    plt.scatter(labels_test, test_predictions, c="brown", label=f'Test Data (Corr: {corr_test:.2f})', s= 10)

    plt.xlabel("Labels")
    plt.ylabel("Predictions")
    plt.legend()
    plt.title("Correlation Plot")
    plt.show()
# Out:
# 0
# Correlation coefficient on test data: 0.8141670909200597
# Correlation coefficient on all data: 0.9767069587103223
# 1
# Correlation coefficient on test data: 0.8377647910672389
# Correlation coefficient on all data: 0.9270277793300554
# 2
# Correlation coefficient on test data: 0.84470114092194
# Correlation coefficient on all data: 0.9108293213726137
# 3
# Correlation coefficient on test data: 0.8516031205781799
# Correlation coefficient on all data: 0.9007483830731519
# 4
# Correlation coefficient on test data: 0.8495436071089305
# Correlation coefficient on all data: 0.8922169535437044
# 5
# Correlation coefficient on test data: 0.8468446213097304
# Correlation coefficient on all data: 0.8806020684027496
# 6
# Correlation coefficient on test data: 0.8494148100964303
# Correlation coefficient on all data: 0.8742144621079732
# 7
# Correlation coefficient on test data: 0.8459644724209253
# Correlation coefficient on all data: 0.8654719593198016
# 8
# Correlation coefficient on test data: 0.8426154985459846
# Correlation coefficient on all data: 0.8599305500879678

# %%
# Initialize KNN regressor with 5 neighbors
knn_regressor = KNeighborsRegressor(n_neighbors=4)

# Train the model on the training set
knn_regressor.fit(features_train, labels_train)

# Predict on the test set
test_predictions = knn_regressor.predict(features_test)
all_predictions = knn_regressor.predict(features_np)

# Calculate the correlation coefficient for test data
corr_test, _ = pearsonr(labels_test, test_predictions)
corr_all, _ = pearsonr(labels_np, all_predictions)
print(f"Correlation coefficient on test data: {corr_test}")
line = np.linspace(0,20,100)


# Create a scatter plot for both test and all data
plt.figure()
plt.plot(line, line, 'r')
plt.scatter(labels_np, all_predictions, c="blue", label=f'All Data (Corr: {corr_all:.2f})', s= 10)
plt.scatter(labels_test, test_predictions, c="brown", label=f'Test Data (Corr: {corr_test:.2f})', s= 10)

plt.xlabel("Labels")
plt.ylabel("Predictions")
plt.legend()
plt.title("Correlation Plot")
plt.show()
# Out:
# Correlation coefficient on test data: 0.8516031205781799

# %%
"""
np.save("all_labels_KNN_DO", labels_np)
np.save("all_predictions_KNN_DO", all_predictions)
np.save("test_labels_KNN_DO", labels_test)
np.save("test_predictions_KNN_DO", test_predictions)
"""
# Out:
# '\nnp.save("all_labels_KNN_DO", labels_np)\nnp.save("all_predictions_KNN_DO", all_predictions)\nnp.save("test_labels_KNN_DO", labels_test)\nnp.save("test_predictions_KNN_DO", test_predictions)\n'

# %%
from pathlib import Path
import pickle
import numpy as np
from matplotlib import pyplot as plt
import os
import gc
from os import walk


#os.chdir("/gxfs_work1/cau/sunms498/work/david/NN4SedRatePred/models/MLP/SedRate_MAR/models_torch/")



feature_path = Path().resolve().parents[1] / "data" / "interim" / "inputfeatures" / "SedTOCFeaturesnoNAN_TOC_DO_men"
X_mean = np.load(Path(feature_path / "features_mean.npy")).astype(float)
X_std = np.load(Path(feature_path / "features_std.npy")).astype(float)

dataset_path = Path().resolve().parents[1] / "data" / "interim" / "worldfeatures" / "WorldFeaturesAllnoNaN_SedTOC"

files = []

for (dirpath, dirnames, filenames) in walk(dataset_path):
    files.extend(filenames)
    break

files.sort()


features = np.load(Path(dataset_path / files[0]))

# %%
features = np.load(Path(dataset_path / files[0]))

chunk_shape = [6,4320] #360 chunks


first_run = True
ii = 0

for count, file in enumerate(files):
    features = np.load(Path(dataset_path / file))
    features = np.divide((features - X_mean), X_std)
    


    # Perform multiple forward passes with dropout
    num_samples = 100  # Adjust this based on your requirements
    #predictions = np.zeros((chunk_shape[0], chunk_shape[1]))

    predictions = knn_regressor.predict(features)
    predictions= predictions.reshape([chunk_shape[0], chunk_shape[1]])

    # Average predictions over all samples
    #predictions_avg = np.mean(predictions_sum, axis=0)
    #predictions_var = np.var(predictions_sum, axis=0)

    if first_run:
        prediction_map2 = predictions
        #prediction_map2_var = predictions_var
        first_run = False
    else:
        prediction_map2 = np.append(prediction_map2, predictions, axis=0)
        #prediction_map2_var = np.append(prediction_map2_var, predictions_var, axis=0)

    ii += 1
    print("Prediction " + str(ii) + " done!")

    del features
    gc.collect()
# Out:
# Prediction 1 done!
# Prediction 2 done!
# Prediction 3 done!
# Prediction 4 done!
# Prediction 5 done!
# Prediction 6 done!
# Prediction 7 done!
# Prediction 8 done!
# Prediction 9 done!
# Prediction 10 done!
# Prediction 11 done!
# Prediction 12 done!
# Prediction 13 done!
# Prediction 14 done!
# Prediction 15 done!
# Prediction 16 done!
# Prediction 17 done!
# Prediction 18 done!
# Prediction 19 done!
# Prediction 20 done!
# Prediction 21 done!
# Prediction 22 done!
# Prediction 23 done!
# Prediction 24 done!
# Prediction 25 done!
# Prediction 26 done!
# Prediction 27 done!
# Prediction 28 done!
# Prediction 29 done!
# Prediction 30 done!
# Prediction 31 done!
# Prediction 32 done!
# Prediction 33 done!
# Prediction 34 done!
# Prediction 35 done!
# Prediction 36 done!
# Prediction 37 done!
# Prediction 38 done!
# Prediction 39 done!
# Prediction 40 done!
# Prediction 41 done!
# Prediction 42 done!
# Prediction 43 done!
# Prediction 44 done!
# Prediction 45 done!
# Prediction 46 done!
# Prediction 47 done!
# Prediction 48 done!
# Prediction 49 done!
# Prediction 50 done!
# Prediction 51 done!
# Prediction 52 done!
# Prediction 53 done!
# Prediction 54 done!
# Prediction 55 done!
# Prediction 56 done!
# Prediction 57 done!
# Prediction 58 done!
# Prediction 59 done!
# Prediction 60 done!
# Prediction 61 done!
# Prediction 62 done!
# Prediction 63 done!
# Prediction 64 done!
# Prediction 65 done!
# Prediction 66 done!
# Prediction 67 done!
# Prediction 68 done!
# Prediction 69 done!
# Prediction 70 done!
# Prediction 71 done!
# Prediction 72 done!
# Prediction 73 done!
# Prediction 74 done!
# Prediction 75 done!
# Prediction 76 done!
# Prediction 77 done!
# Prediction 78 done!
# Prediction 79 done!
# Prediction 80 done!
# Prediction 81 done!
# Prediction 82 done!
# Prediction 83 done!
# Prediction 84 done!
# Prediction 85 done!
# Prediction 86 done!
# Prediction 87 done!
# Prediction 88 done!
# Prediction 89 done!
# Prediction 90 done!
# Prediction 91 done!
# Prediction 92 done!
# Prediction 93 done!
# Prediction 94 done!
# Prediction 95 done!
# Prediction 96 done!
# Prediction 97 done!
# Prediction 98 done!
# Prediction 99 done!
# Prediction 100 done!
# Prediction 101 done!
# Prediction 102 done!
# Prediction 103 done!
# Prediction 104 done!
# Prediction 105 done!
# Prediction 106 done!
# Prediction 107 done!
# Prediction 108 done!
# Prediction 109 done!
# Prediction 110 done!
# Prediction 111 done!
# Prediction 112 done!
# Prediction 113 done!
# Prediction 114 done!
# Prediction 115 done!
# Prediction 116 done!
# Prediction 117 done!
# Prediction 118 done!
# Prediction 119 done!
# Prediction 120 done!
# Prediction 121 done!
# Prediction 122 done!
# Prediction 123 done!
# Prediction 124 done!
# Prediction 125 done!
# Prediction 126 done!
# Prediction 127 done!
# Prediction 128 done!
# Prediction 129 done!
# Prediction 130 done!
# Prediction 131 done!
# Prediction 132 done!
# Prediction 133 done!
# Prediction 134 done!
# Prediction 135 done!
# Prediction 136 done!
# Prediction 137 done!
# Prediction 138 done!
# Prediction 139 done!
# Prediction 140 done!
# Prediction 141 done!
# Prediction 142 done!
# Prediction 143 done!
# Prediction 144 done!
# Prediction 145 done!
# Prediction 146 done!
# Prediction 147 done!
# Prediction 148 done!
# Prediction 149 done!
# Prediction 150 done!
# Prediction 151 done!
# Prediction 152 done!
# Prediction 153 done!
# Prediction 154 done!
# Prediction 155 done!
# Prediction 156 done!
# Prediction 157 done!
# Prediction 158 done!
# Prediction 159 done!
# Prediction 160 done!
# Prediction 161 done!
# Prediction 162 done!
# Prediction 163 done!
# Prediction 164 done!
# Prediction 165 done!
# Prediction 166 done!
# Prediction 167 done!
# Prediction 168 done!
# Prediction 169 done!
# Prediction 170 done!
# Prediction 171 done!
# Prediction 172 done!
# Prediction 173 done!
# Prediction 174 done!
# Prediction 175 done!
# Prediction 176 done!
# Prediction 177 done!
# Prediction 178 done!
# Prediction 179 done!
# Prediction 180 done!
# Prediction 181 done!
# Prediction 182 done!
# Prediction 183 done!
# Prediction 184 done!
# Prediction 185 done!
# Prediction 186 done!
# Prediction 187 done!
# Prediction 188 done!
# Prediction 189 done!
# Prediction 190 done!
# Prediction 191 done!
# Prediction 192 done!
# Prediction 193 done!
# Prediction 194 done!
# Prediction 195 done!
# Prediction 196 done!
# Prediction 197 done!
# Prediction 198 done!
# Prediction 199 done!
# Prediction 200 done!
# Prediction 201 done!
# Prediction 202 done!
# Prediction 203 done!
# Prediction 204 done!
# Prediction 205 done!
# Prediction 206 done!
# Prediction 207 done!
# Prediction 208 done!
# Prediction 209 done!
# Prediction 210 done!
# Prediction 211 done!
# Prediction 212 done!
# Prediction 213 done!
# Prediction 214 done!
# Prediction 215 done!
# Prediction 216 done!
# Prediction 217 done!
# Prediction 218 done!
# Prediction 219 done!
# Prediction 220 done!
# Prediction 221 done!
# Prediction 222 done!
# Prediction 223 done!
# Prediction 224 done!
# Prediction 225 done!
# Prediction 226 done!
# Prediction 227 done!
# Prediction 228 done!
# Prediction 229 done!
# Prediction 230 done!
# Prediction 231 done!
# Prediction 232 done!
# Prediction 233 done!
# Prediction 234 done!
# Prediction 235 done!
# Prediction 236 done!
# Prediction 237 done!
# Prediction 238 done!
# Prediction 239 done!
# Prediction 240 done!
# Prediction 241 done!
# Prediction 242 done!
# Prediction 243 done!
# Prediction 244 done!
# Prediction 245 done!
# Prediction 246 done!
# Prediction 247 done!
# Prediction 248 done!
# Prediction 249 done!
# Prediction 250 done!
# Prediction 251 done!
# Prediction 252 done!
# Prediction 253 done!
# Prediction 254 done!
# Prediction 255 done!
# Prediction 256 done!
# Prediction 257 done!
# Prediction 258 done!
# Prediction 259 done!
# Prediction 260 done!
# Prediction 261 done!
# Prediction 262 done!
# Prediction 263 done!
# Prediction 264 done!
# Prediction 265 done!
# Prediction 266 done!
# Prediction 267 done!
# Prediction 268 done!
# Prediction 269 done!
# Prediction 270 done!
# Prediction 271 done!
# Prediction 272 done!
# Prediction 273 done!
# Prediction 274 done!
# Prediction 275 done!
# Prediction 276 done!
# Prediction 277 done!
# Prediction 278 done!
# Prediction 279 done!
# Prediction 280 done!
# Prediction 281 done!
# Prediction 282 done!
# Prediction 283 done!
# Prediction 284 done!
# Prediction 285 done!
# Prediction 286 done!
# Prediction 287 done!
# Prediction 288 done!
# Prediction 289 done!
# Prediction 290 done!
# Prediction 291 done!
# Prediction 292 done!
# Prediction 293 done!
# Prediction 294 done!
# Prediction 295 done!
# Prediction 296 done!
# Prediction 297 done!
# Prediction 298 done!
# Prediction 299 done!
# Prediction 300 done!
# Prediction 301 done!
# Prediction 302 done!
# Prediction 303 done!
# Prediction 304 done!
# Prediction 305 done!
# Prediction 306 done!
# Prediction 307 done!
# Prediction 308 done!
# Prediction 309 done!
# Prediction 310 done!
# Prediction 311 done!
# Prediction 312 done!
# Prediction 313 done!
# Prediction 314 done!
# Prediction 315 done!
# Prediction 316 done!
# Prediction 317 done!
# Prediction 318 done!
# Prediction 319 done!
# Prediction 320 done!
# Prediction 321 done!
# Prediction 322 done!
# Prediction 323 done!
# Prediction 324 done!
# Prediction 325 done!
# Prediction 326 done!
# Prediction 327 done!
# Prediction 328 done!
# Prediction 329 done!
# Prediction 330 done!
# Prediction 331 done!
# Prediction 332 done!
# Prediction 333 done!
# Prediction 334 done!
# Prediction 335 done!
# Prediction 336 done!
# Prediction 337 done!
# Prediction 338 done!
# Prediction 339 done!
# Prediction 340 done!
# Prediction 341 done!
# Prediction 342 done!
# Prediction 343 done!
# Prediction 344 done!
# Prediction 345 done!
# Prediction 346 done!
# Prediction 347 done!
# Prediction 348 done!
# Prediction 349 done!
# Prediction 350 done!
# Prediction 351 done!
# Prediction 352 done!
# Prediction 353 done!
# Prediction 354 done!
# Prediction 355 done!
# Prediction 356 done!
# Prediction 357 done!
# Prediction 358 done!
# Prediction 359 done!
# Prediction 360 done!

# %%
predictions.shape
# Out:
# (6, 4320)

# %%
land_file = Path().resolve().parents[2] / "nn4sedratetoc" / "data" / "raw" / "island_map.npy"
land_map = np.load(land_file)
land_map[np.isnan(land_map)] = 1
#prediction_map2[land_map] = 0

#plt.figure(figsize=[25,15], dpi=200)

# %%
import matplotlib.colors as mcolors
prediction_map2 = np.rot90(np.rot90(np.fliplr(prediction_map2)))
plt.figure(figsize=[25, 15], dpi=50)
prediction_map2[land_map] = 0
plt.imshow(prediction_map2, norm=mcolors.LogNorm(vmin=1e-1, vmax=1e1),cmap="cubehelix")
cbar = plt.colorbar()

# %%
np.save( Path().resolve().parents[1]  / "data" / "output" / "predictionmaps_TOC" / "prediction_map_TOC_supervised_men_DO_KNN.npy", prediction_map2)
